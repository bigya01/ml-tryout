# %% [markdown]
# <a href="https://colab.research.google.com/github/bigya01/ml-tryout/blob/main/day11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install numpy scipy matplotlib ipython scikit-learn pandas mglearn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 19.0 MB/s eta 0:00:00
# ...

# %%
import mglearn
import pandas as pd
import mglearn
import numpy as np

# %%
mglearn.plots.plot_knn_regression(n_neighbors=1)
